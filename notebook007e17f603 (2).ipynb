# %% [markdown]
#  The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/creditcardfraud/creditcard.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("/kaggle/input/creditcardfraud/creditcard.csv", sep= ',')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
sns.countplot(df['Class'])
plt.show()

# %% [markdown]
# seeems like the data is imbalanced so we need imbalanced learn package

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN
from imblearn.metrics import classification_report_imbalanced

# %%
#let's do some EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
#let's visualize classes
d1= pd.DataFrame(df.groupby(['Class'])['Class'].count())
fig,axes=plt.subplots(figsize= (12,10), dpi= 70)
axes.barh([0],d1.Class[0], height= 0.7, color= 'black')
plt.text(290000,0.08, '99.8%',{'fontname':'Serif','weight':'bold' ,'size':'16','color':'black'})
axes.barh([1], d1.Class[1] ,height= 0.7, color= 'red')
plt.text(3900,1, '0.17%',{'fontname':'Serif', 'weight':'bold','size':'16','color':'red'})

axes.axes.get_xaxis().set_visible(False)
axes.axes.get_yaxis().set_visible(False)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
plt.show()

# %%
#let's do it without sampling and with oversampling
sns.distplot(df['Time'])
plt.show()

# %%
sns.distplot(df['Amount'])
plt.show()

# %%
sns.scatterplot(x= 'Time', y='Amount', hue= 'Class', data = df)

plt.show()

# %%
sns.boxplot(x=df['Class'], y=df['Amount'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Amount'>

# %% [markdown]
# looks like there are outliers

# %%
#let's checl correrlation now
plt.figure(figsize= (19,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#becuasue of outliers let;s scale it
from sklearn.preprocessing import RobustScaler

rbst= RobustScaler()

# %%
df['Amount']= rbst.fit_transform(df['Amount'].values.reshape(-1,1))
df['Time']= rbst.fit_transform(df['Time'].values.reshape(-1,1))

# %%
target = 'Class'
predictors = ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',\
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19',\
       'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',\
       'Amount']

# %% [markdown]
# ### splitting training and testing set

# %%
X= df.drop('Class', axis =1)
Y= df.Class.values

# %%
Y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0      -0.994983  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1      -0.994983   1.191857   0.266151  0.166480  0.448154  0.060018
# 2      -0.994972  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3      -0.994972  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4      -0.994960  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  1.034951 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  1.034963  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  1.034975   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  1.034975  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  1.035022  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# 0       0.462388  0.239599  0.098698  0.363787  ...  0.251412 -0.018307
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.524980  0.247998
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300
# 4       0.095921  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  1.475829  0.213454
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.059616  0.214205
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.001396  0.232045
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.127434  0.265245
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#           Amount
# 0       1.783274
# 1      -0.269825
# 2       4.983721
# 3       1.418291
# 4       0.670579
# ...          ...
# 284802 -0.296653
# 284803  0.038986
# 284804  0.641096
# 284805 -0.167680
# 284806  2.724796
#
# [284807 rows x 30 columns]

# %% [markdown]
# ##### importing relevant libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

from sklearn.neighbors import KNeighborsClassifier as Knn
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier , AdaBoostClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor


from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report , confusion_matrix
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
X_train,X_test,y_train,y_test= train_test_split(X,Y,test_size= 0.2, random_state= 10)

# %%
# a fucntion to see things easi;ly
def predict(model,X_train, X_test, y_train, y_test):
    model.fit(X_train,y_train)
    preds=model.predict(X_test)
    print(confusion_matrix(y_test,preds))
    print(classification_report(y_test,preds))
    print("roc_score",roc_auc_score(y_test, preds))
    print("Precision :",metrics.precision_score(y_test, preds))
    print("Recall :",metrics.recall_score(y_test, preds))
    fig, axes = plt.subplots(1,2,figsize=(27,12))
    
    axes[0].set_title("Confusion Matrix")
    sns.heatmap(confusion_matrix(y_test,preds),annot=True,fmt='0.0f',ax=axes[0],cmap="YlGnBu")

   
    plt.show()
   
    
    return accuracy_score(y_test,preds)

# %%
# a fucntion to see things easi;ly
def predict2(model,X_train, X_test, y_train, y_test):
    model.fit(X_train,y_train)
    preds=model.predict(X_test)
    print(confusion_matrix(y_test,preds))
    print(classification_report(y_test,preds))
    print("Precision Neural Net:",metrics.precision_score(y_test, preds))
    print("Recall Neural Net:",metrics.recall_score(y_test, preds))
    print("roc_score",roc_auc_score(y_test, preds))
    fig, axes = plt.subplots(1,2,figsize=(27,12))
    
    axes[0].set_title("Confusion Matrix")
    sns.heatmap(confusion_matrix(y_test,preds),annot=True,fmt='0.0f',ax=axes[0],cmap="YlGnBu")

    tmp = pd.DataFrame({'Feature': predictors, 'Feature importance': model.feature_importances_})
    tmp = tmp.sort_values(by='Feature importance',ascending=False)
    s = sns.barplot(x='Feature',y='Feature importance',data=tmp,color='red',ax=axes[1])
    axes[1].set_title("Feature Importance")
    plt.show()
    return accuracy_score(y_test,preds)

# %%
predict(LogisticRegression(max_iter=50000), X_train, X_test, y_train, y_test)
# Out:
# [[56859     9]
#  [   31    63]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.88      0.67      0.76        94
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.84      0.88     56962
# weighted avg       1.00      1.00      1.00     56962
#
# roc_score 0.8350272523604495
# Precision : 0.875
# Recall : 0.6702127659574468
# 0.9992977774656788

# %%
predict2(xgb.XGBClassifier(silent=True,max_depth=2,tree_method = 'gpu_hist',predictor='gpu_predictor',eval_metric='auc'),X_train,X_test, y_train, y_test)
# Out:
# [17:08:59] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [[56866     2]
#  [   17    77]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.97      0.82      0.89        94
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.91      0.95     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Precision Neural Net: 0.9746835443037974
# Recall Neural Net: 0.8191489361702128
# roc_score 0.9095568835032677
# 0.9996664442961974

# %%
predict2(RandomForestClassifier(n_estimators=100,n_jobs=4,verbose=False),X_train,X_test, y_train, y_test)
# Out:
# [[56866     2]
#  [   16    78]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.97      0.83      0.90        94
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.91      0.95     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Precision Neural Net: 0.975
# Recall Neural Net: 0.8297872340425532
# roc_score 0.9148760324394379
# 0.9996839998595555

# %%
predict2(AdaBoostClassifier(random_state=42,
                        algorithm='SAMME.R',
                         learning_rate=0.8,),X_train,X_test, y_train, y_test)
# Out:
# [[56857    11]
#  [   19    75]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.87      0.80      0.83        94
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.90      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Precision Neural Net: 0.872093023255814
# Recall Neural Net: 0.7978723404255319
# roc_score 0.8988394550126534
# 0.9994733330992591

# %%
predict2(lgb.LGBMClassifier(
    objective='binary',
        metric = 'auc',
          learning_rate= 0.05,
          num_leaves =  7,max_depth=4,min_child_samples= 100,  
          max_bin=100,device= 'gpu'),X_train,X_test, y_train, y_test)
# Out:
# [[56853    15]
#  [   30    64]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.81      0.68      0.74        94
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.84      0.87     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Precision Neural Net: 0.810126582278481
# Recall Neural Net: 0.6808510638297872
# roc_score 0.8402936475511038
# 0.9992099996488887

# %%
predict(Knn(n_neighbors=5),X_train,X_test,y_train,y_test)
# Out:
# [[56867     1]
#  [   22    72]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.99      0.77      0.86        94
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.88      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
# roc_score 0.882969931113336
# Precision : 0.9863013698630136
# Recall : 0.7659574468085106
# 0.9995962220427653

# %%
predict(GaussianNB(),X_train,X_test,y_train,y_test )
# Out:
# [[55575  1293]
#  [   16    78]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56868
#            1       0.06      0.83      0.11        94
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.90      0.55     56962
# weighted avg       1.00      0.98      0.99     56962
#
# roc_score 0.9035251848625933
# Precision : 0.05689277899343545
# Recall : 0.8297872340425532
# 0.9770197675643412

# %% [markdown]
# now le'ts try same after sampling

# %%
smt = SMOTE(random_state=42)
# adasyn = ADASYN(random_state=42)
X_smote,Y_smote = smt.fit_resample(X_train,y_train)

# %%
predict(LogisticRegression(max_iter=50000), X_smote, X_test, Y_smote, y_test)
# Out:
# [[55409  1459]
#  [    8    86]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56868
#            1       0.06      0.91      0.10        94
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.94      0.55     56962
# weighted avg       1.00      0.97      0.99     56962
#
# roc_score 0.9446188560593476
# Precision : 0.05566343042071197
# Recall : 0.9148936170212766
# 0.9742459885537726

# %%
predict2(xgb.XGBClassifier(silent=True,max_depth=2,tree_method = 'gpu_hist',predictor='gpu_predictor',eval_metric='auc'),X_smote,X_test, Y_smote, y_test)
# Out:
# [17:15:07] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [[56354   514]
#  [   12    82]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56868
#            1       0.14      0.87      0.24        94
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.93      0.62     56962
# weighted avg       1.00      0.99      0.99     56962
#
# Precision Neural Net: 0.13758389261744966
# Recall Neural Net: 0.8723404255319149
# roc_score 0.931650975233426
# 0.9907657736736772

# %%
predict2(RandomForestClassifier(n_estimators=100,n_jobs=4,verbose=False),X_smote,X_test, Y_smote, y_test)
# Out:
# [[56857    11]
#  [   17    77]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.88      0.82      0.85        94
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.91      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Precision Neural Net: 0.875
# Recall Neural Net: 0.8191489361702128
# roc_score 0.9094777528849938
# 0.9995084442259752

# %%
predict2(AdaBoostClassifier(random_state=42,
                        algorithm='SAMME.R',
                         learning_rate=0.8,),X_smote,X_test, Y_smote, y_test)
# Out:
# [[55579  1289]
#  [   11    83]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56868
#            1       0.06      0.88      0.11        94
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.93      0.55     56962
# weighted avg       1.00      0.98      0.99     56962
#
# Precision Neural Net: 0.060495626822157436
# Recall Neural Net: 0.8829787234042553
# roc_score 0.9301560987071217
# 0.9771777676345634

# %%
predict2(lgb.LGBMClassifier(
    objective='binary',
        metric = 'auc',
          learning_rate= 0.05,
          num_leaves =  7,max_depth=4,min_child_samples= 100,  
          max_bin=100,device= 'gpu'),X_smote,X_test, Y_smote, y_test)
# Out:
# [[55843  1025]
#  [    9    85]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56868
#            1       0.08      0.90      0.14        94
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.94      0.57     56962
# weighted avg       1.00      0.98      0.99     56962
#
# Precision Neural Net: 0.07657657657657657
# Recall Neural Net: 0.9042553191489362
# roc_score 0.9431155613821631
# 0.9818475474877989

# %% [markdown]
# now let's try some feature selection to see if we can improve it a bit further using xgb

# %% [markdown]
# fun thing is all plots are showing that Amount really has small importance which is quite interesting but mostly it depends on
# V14, V10 , v4 and v17 in few cases

# %%
model =xgb.XGBClassifier(silent=True,max_depth=2,tree_method = 'gpu_hist',predictor='gpu_predictor',eval_metric='auc')

# %%
model.fit(X_smote,Y_smote)
# Out:
# [17:21:20] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='auc', gamma=0, gpu_id=0, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=2, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=2,
#               num_parallel_tree=1, predictor='gpu_predictor', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, silent=True,
#               subsample=1, tree_method='gpu_hist', validate_parameters=1,
#               verbosity=None)

# %%
slm = SelectFromModel(model, threshold = 0.2)

# %%
X_train_XGB =slm.fit_transform(X_smote,Y_smote)
# Out:
# [17:21:21] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
#need to select same features as train dataset
X_test_XGB= np.array(X_test[X_test.columns[slm.get_support()]])

# %%
X_train_XGB
# Out:
# array([[ -0.0694688 ],
#        [ -0.87780134],
#        [ -0.77346466],
#        ...,
#        [ -1.74622822],
#        [ -4.28410462],
#        [-13.43101905]])

# %%
#preparing the train and test datasets
d_train= xgb.DMatrix(pd.DataFrame(X_train_XGB), Y_smote)
d_test= xgb.DMatrix(pd.DataFrame(X_test_XGB),y_test)

##to monitor train and  test
watch_list= [(d_train,'train'), (d_test, 'test')]

# %%
params = {}
params['objective'] = 'binary:logistic'
params['silent'] = True
params['max_depth'] = 2
params['eval_metric'] = 'auc'
params['random_state'] = 50
params['tree_method'] = 'gpu_hist'
params['predictor']='gpu_predictor'

# %%
model1 = xgb.train(params,d_train,200, watch_list)
# Out:
# [17:21:23] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.94969	test-auc:0.95638
# [1]	train-auc:0.95110	test-auc:0.96450
# [2]	train-auc:0.95163	test-auc:0.96486
# [3]	train-auc:0.95188	test-auc:0.96541
# [4]	train-auc:0.95218	test-auc:0.96542
# [5]	train-auc:0.95420	test-auc:0.96714
# [6]	train-auc:0.95422	test-auc:0.96731
# [7]	train-auc:0.95451	test-auc:0.96783
# [8]	train-auc:0.95616	test-auc:0.96359
# [9]	train-auc:0.95616	test-auc:0.96351
# [10]	train-auc:0.95617	test-auc:0.96351
# [11]	train-auc:0.95630	test-auc:0.96364
# [12]	train-auc:0.95630	test-auc:0.96364
# [13]	train-auc:0.95631	test-auc:0.96367
# [14]	train-auc:0.95631	test-auc:0.96367
# [15]	train-auc:0.95651	test-auc:0.96420
# [16]	train-auc:0.95667	test-auc:0.96396
# [17]	train-auc:0.95667	test-auc:0.96396
# [18]	train-auc:0.95667	test-auc:0.96396
# [19]	train-auc:0.95667	test-auc:0.96396
# [20]	train-auc:0.95703	test-auc:0.96352
# [21]	train-auc:0.95689	test-auc:0.96400
# [22]	train-auc:0.95704	test-auc:0.96376
# [23]	train-auc:0.95739	test-auc:0.96343
# [24]	train-auc:0.95739	test-auc:0.96343
# [25]	train-auc:0.95766	test-auc:0.96478
# [26]	train-auc:0.95768	test-auc:0.96454
# [27]	train-auc:0.95784	test-auc:0.96454
# [28]	train-auc:0.95789	test-auc:0.96447
# [29]	train-auc:0.95789	test-auc:0.96447
# [30]	train-auc:0.95791	test-auc:0.96463
# [31]	train-auc:0.95798	test-auc:0.96395
# [32]	train-auc:0.95800	test-auc:0.96395
# [33]	train-auc:0.95801	test-auc:0.96394
# [34]	train-auc:0.95812	test-auc:0.96388
# [35]	train-auc:0.95823	test-auc:0.96422
# [36]	train-auc:0.95824	test-auc:0.96406
# [37]	train-auc:0.95825	test-auc:0.96406
# [38]	train-auc:0.95825	test-auc:0.96422
# [39]	train-auc:0.95825	test-auc:0.96422
# [40]	train-auc:0.95827	test-auc:0.96415
# [41]	train-auc:0.95830	test-auc:0.96429
# [42]	train-auc:0.95831	test-auc:0.96412
# [43]	train-auc:0.95831	test-auc:0.96412
# [44]	train-auc:0.95831	test-auc:0.96412
# [45]	train-auc:0.95841	test-auc:0.96412
# [46]	train-auc:0.95841	test-auc:0.96422
# [47]	train-auc:0.95847	test-auc:0.96347
# [48]	train-auc:0.95847	test-auc:0.96347
# [49]	train-auc:0.95848	test-auc:0.96378
# [50]	train-auc:0.95848	test-auc:0.96371
# [51]	train-auc:0.95848	test-auc:0.96371
# [52]	train-auc:0.95850	test-auc:0.96371
# [53]	train-auc:0.95850	test-auc:0.96371
# [54]	train-auc:0.95850	test-auc:0.96368
# [55]	train-auc:0.95850	test-auc:0.96368
# [56]	train-auc:0.95850	test-auc:0.96368
# [57]	train-auc:0.95851	test-auc:0.96367
# [58]	train-auc:0.95851	test-auc:0.96367
# [59]	train-auc:0.95851	test-auc:0.96367
# [60]	train-auc:0.95851	test-auc:0.96367
# [61]	train-auc:0.95851	test-auc:0.96380
# [62]	train-auc:0.95851	test-auc:0.96380
# [63]	train-auc:0.95851	test-auc:0.96380
# [64]	train-auc:0.95852	test-auc:0.96380
# [65]	train-auc:0.95854	test-auc:0.96344
# [66]	train-auc:0.95860	test-auc:0.96344
# [67]	train-auc:0.95861	test-auc:0.96344
# [68]	train-auc:0.95861	test-auc:0.96344
# [69]	train-auc:0.95861	test-auc:0.96344
# [70]	train-auc:0.95863	test-auc:0.96315
# [71]	train-auc:0.95863	test-auc:0.96315
# [72]	train-auc:0.95863	test-auc:0.96318
# [73]	train-auc:0.95863	test-auc:0.96318
# [74]	train-auc:0.95864	test-auc:0.96330
# [75]	train-auc:0.95864	test-auc:0.96340
# [76]	train-auc:0.95866	test-auc:0.96340
# [77]	train-auc:0.95866	test-auc:0.96329
# [78]	train-auc:0.95866	test-auc:0.96329
# [79]	train-auc:0.95866	test-auc:0.96329
# [80]	train-auc:0.95866	test-auc:0.96329
# [81]	train-auc:0.95867	test-auc:0.96281
# [82]	train-auc:0.95867	test-auc:0.96281
# [83]	train-auc:0.95867	test-auc:0.96281
# [84]	train-auc:0.95867	test-auc:0.96281
# [85]	train-auc:0.95867	test-auc:0.96281
# [86]	train-auc:0.95867	test-auc:0.96281
# [87]	train-auc:0.95867	test-auc:0.96281
# [88]	train-auc:0.95867	test-auc:0.96281
# [89]	train-auc:0.95867	test-auc:0.96281
# [90]	train-auc:0.95867	test-auc:0.96281
# [91]	train-auc:0.95867	test-auc:0.96281
# [92]	train-auc:0.95867	test-auc:0.96281
# [93]	train-auc:0.95867	test-auc:0.96281
# [94]	train-auc:0.95867	test-auc:0.96281
# [95]	train-auc:0.95867	test-auc:0.96281
# [96]	train-auc:0.95867	test-auc:0.96281
# [97]	train-auc:0.95867	test-auc:0.96281
# [98]	train-auc:0.95867	test-auc:0.96281
# [99]	train-auc:0.95867	test-auc:0.96281
# [100]	train-auc:0.95867	test-auc:0.96281
# [101]	train-auc:0.95867	test-auc:0.96281
# [102]	train-auc:0.95867	test-auc:0.96281
# [103]	train-auc:0.95867	test-auc:0.96281
# [104]	train-auc:0.95867	test-auc:0.96281
# [105]	train-auc:0.95867	test-auc:0.96281
# [106]	train-auc:0.95867	test-auc:0.96281
# [107]	train-auc:0.95867	test-auc:0.96281
# [108]	train-auc:0.95867	test-auc:0.96281
# [109]	train-auc:0.95867	test-auc:0.96281
# [110]	train-auc:0.95867	test-auc:0.96281
# [111]	train-auc:0.95867	test-auc:0.96281
# [112]	train-auc:0.95867	test-auc:0.96281
# [113]	train-auc:0.95867	test-auc:0.96281
# [114]	train-auc:0.95867	test-auc:0.96281
# [115]	train-auc:0.95867	test-auc:0.96281
# [116]	train-auc:0.95867	test-auc:0.96281
# [117]	train-auc:0.95867	test-auc:0.96281
# [118]	train-auc:0.95867	test-auc:0.96281
# [119]	train-auc:0.95867	test-auc:0.96281
# [120]	train-auc:0.95867	test-auc:0.96281
# [121]	train-auc:0.95867	test-auc:0.96281
# [122]	train-auc:0.95867	test-auc:0.96281
# [123]	train-auc:0.95867	test-auc:0.96281
# [124]	train-auc:0.95867	test-auc:0.96281
# [125]	train-auc:0.95867	test-auc:0.96281
# [126]	train-auc:0.95867	test-auc:0.96281
# [127]	train-auc:0.95867	test-auc:0.96281
# [128]	train-auc:0.95867	test-auc:0.96281
# [129]	train-auc:0.95867	test-auc:0.96281
# [130]	train-auc:0.95867	test-auc:0.96281
# [131]	train-auc:0.95867	test-auc:0.96281
# [132]	train-auc:0.95867	test-auc:0.96281
# [133]	train-auc:0.95867	test-auc:0.96281
# [134]	train-auc:0.95867	test-auc:0.96281
# [135]	train-auc:0.95867	test-auc:0.96281
# [136]	train-auc:0.95867	test-auc:0.96281
# [137]	train-auc:0.95867	test-auc:0.96281
# [138]	train-auc:0.95867	test-auc:0.96281
# [139]	train-auc:0.95867	test-auc:0.96281
# [140]	train-auc:0.95867	test-auc:0.96281
# [141]	train-auc:0.95867	test-auc:0.96281
# [142]	train-auc:0.95867	test-auc:0.96281
# [143]	train-auc:0.95867	test-auc:0.96281
# [144]	train-auc:0.95867	test-auc:0.96281
# [145]	train-auc:0.95867	test-auc:0.96281
# [146]	train-auc:0.95867	test-auc:0.96281
# [147]	train-auc:0.95867	test-auc:0.96281
# [148]	train-auc:0.95867	test-auc:0.96281
# [149]	train-auc:0.95867	test-auc:0.96281
# [150]	train-auc:0.95867	test-auc:0.96281
# [151]	train-auc:0.95867	test-auc:0.96281
# [152]	train-auc:0.95867	test-auc:0.96281
# [153]	train-auc:0.95867	test-auc:0.96281
# [154]	train-auc:0.95867	test-auc:0.96281
# [155]	train-auc:0.95867	test-auc:0.96281
# [156]	train-auc:0.95867	test-auc:0.96281
# [157]	train-auc:0.95867	test-auc:0.96281
# [158]	train-auc:0.95867	test-auc:0.96281
# [159]	train-auc:0.95867	test-auc:0.96281
# [160]	train-auc:0.95867	test-auc:0.96281
# [161]	train-auc:0.95867	test-auc:0.96281
# [162]	train-auc:0.95867	test-auc:0.96281
# [163]	train-auc:0.95867	test-auc:0.96281
# [164]	train-auc:0.95867	test-auc:0.96281
# [165]	train-auc:0.95867	test-auc:0.96281
# [166]	train-auc:0.95867	test-auc:0.96281
# [167]	train-auc:0.95867	test-auc:0.96281
# [168]	train-auc:0.95867	test-auc:0.96281
# [169]	train-auc:0.95867	test-auc:0.96281
# [170]	train-auc:0.95867	test-auc:0.96281
# [171]	train-auc:0.95867	test-auc:0.96281
# [172]	train-auc:0.95867	test-auc:0.96281
# [173]	train-auc:0.95867	test-auc:0.96281
# [174]	train-auc:0.95867	test-auc:0.96281
# [175]	train-auc:0.95867	test-auc:0.96281
# [176]	train-auc:0.95867	test-auc:0.96281
# [177]	train-auc:0.95867	test-auc:0.96281
# [178]	train-auc:0.95867	test-auc:0.96281
# [179]	train-auc:0.95867	test-auc:0.96281
# [180]	train-auc:0.95867	test-auc:0.96281
# [181]	train-auc:0.95867	test-auc:0.96281
# [182]	train-auc:0.95867	test-auc:0.96281
# [183]	train-auc:0.95867	test-auc:0.96281
# [184]	train-auc:0.95867	test-auc:0.96281
# [185]	train-auc:0.95867	test-auc:0.96281
# [186]	train-auc:0.95867	test-auc:0.96281
# [187]	train-auc:0.95867	test-auc:0.96281
# [188]	train-auc:0.95867	test-auc:0.96281
# [189]	train-auc:0.95867	test-auc:0.96281
# [190]	train-auc:0.95867	test-auc:0.96281
# [191]	train-auc:0.95867	test-auc:0.96281
# [192]	train-auc:0.95867	test-auc:0.96281
# [193]	train-auc:0.95867	test-auc:0.96281
# [194]	train-auc:0.95867	test-auc:0.96281
# [195]	train-auc:0.95867	test-auc:0.96281
# [196]	train-auc:0.95867	test-auc:0.96281
# [197]	train-auc:0.95867	test-auc:0.96281
# [198]	train-auc:0.95867	test-auc:0.96281
# [199]	train-auc:0.95867	test-auc:0.96281

# %%
preds=model1.predict(d_test)

# %%
xgb.plot_importance(model1, height=0.8, title="Feature importance ",color='red',show_values=False)
# Out:
# <AxesSubplot:title={'center':'Feature importance '}, xlabel='F score', ylabel='Features'>

# %%
roc_auc_score(y_test ,preds)
# Out:
# 0.9628147827219136

# %% [markdown]
# looks like ML models are quite good for these but accuracy does decrease when you use balanced data now let's try some neural networks on these

# %%
#let's try with imbalanced data for now
import tensorflow as tf
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers

from keras.layers.recurrent import LSTM

# %%
n_inputs = len(X_train.columns)

# %%
model = Sequential()

# First Hidden Layer 
model.add(Dense(50, input_dim = n_inputs, activation = 'relu', kernel_initializer = 'he_uniform'))

# Define output layer
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# 2021-11-16 17:21:32.092216: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:32.093382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:32.094064: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:32.094877: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-16 17:21:32.096135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:32.096786: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:32.097394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:35.852410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:35.853189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:35.853867: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-16 17:21:35.854444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14933 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.compile(
    loss = 'binary_crossentropy',
    optimizer = 'adam'
)

# %%
model.fit(X_train, y_train, epochs = 20)
# Out:
# 2021-11-16 17:21:37.574453: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 7121/7121 [==============================] - 18s 2ms/step - loss: 0.0115
# Epoch 2/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0033
# Epoch 3/20
# 7121/7121 [==============================] - 16s 2ms/step - loss: 0.0028
# Epoch 4/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0027
# Epoch 5/20
# 7121/7121 [==============================] - 16s 2ms/step - loss: 0.0026
# Epoch 6/20
# 7121/7121 [==============================] - 18s 3ms/step - loss: 0.0023
# Epoch 7/20
# 7121/7121 [==============================] - 16s 2ms/step - loss: 0.0022
# Epoch 8/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0021
# Epoch 9/20
# 7121/7121 [==============================] - 16s 2ms/step - loss: 0.0020
# Epoch 10/20
# 7121/7121 [==============================] - 18s 3ms/step - loss: 0.0019
# Epoch 11/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0019
# Epoch 12/20
# 7121/7121 [==============================] - 18s 2ms/step - loss: 0.0018
# Epoch 13/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0017
# Epoch 14/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0017
# Epoch 15/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0016
# Epoch 16/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0015
# Epoch 17/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0016
# Epoch 18/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0014
# Epoch 19/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0014
# Epoch 20/20
# 7121/7121 [==============================] - 17s 2ms/step - loss: 0.0014

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))
# Out:
# Accuracy Neural Net: 0.9983497770443454
# Precision Neural Net: 0.0
# Recall Neural Net: 0.0
# F1 Score Neural Net: 0.0

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.9593915884339844

# %%
#not bad now lets try with smote balanced one
model.fit(X_smote, Y_smote, epochs = 20)
# Out:
# Epoch 1/20
# 14216/14216 [==============================] - 35s 2ms/step - loss: 0.0088
# Epoch 2/20
# 14216/14216 [==============================] - 34s 2ms/step - loss: 0.0036
# Epoch 3/20
# 14216/14216 [==============================] - 35s 2ms/step - loss: 0.0023
# Epoch 4/20
# 14216/14216 [==============================] - 35s 2ms/step - loss: 0.0020
# Epoch 5/20
# 14216/14216 [==============================] - 35s 2ms/step - loss: 0.0016
# Epoch 6/20
# 14216/14216 [==============================] - 34s 2ms/step - loss: 0.0014
# Epoch 7/20
# 14216/14216 [==============================] - 35s 2ms/step - loss: 0.0012
# Epoch 8/20
# 14216/14216 [==============================] - 34s 2ms/step - loss: 0.0012
# Epoch 9/20
# 14216/14216 [==============================] - 34s 2ms/step - loss: 9.7506e-04
# Epoch 10/20
# 14216/14216 [==============================] - 36s 3ms/step - loss: 9.2371e-04
# Epoch 11/20
# 14216/14216 [==============================] - 33s 2ms/step - loss: 9.2759e-04
# Epoch 12/20
# 14216/14216 [==============================] - 36s 3ms/step - loss: 9.3339e-04
# Epoch 13/20
# 14216/14216 [==============================] - 34s 2ms/step - loss: 7.5069e-04
# Epoch 14/20
# 14216/14216 [==============================] - 36s 3ms/step - loss: 6.9314e-04
# Epoch 15/20
# 14216/14216 [==============================] - 33s 2ms/step - loss: 6.9749e-04
# Epoch 16/20
# 14216/14216 [==============================] - 36s 3ms/step - loss: 8.2329e-04
# Epoch 17/20
# 14216/14216 [==============================] - 34s 2ms/step - loss: 6.4620e-04
# Epoch 18/20
# 14216/14216 [==============================] - 37s 3ms/step - loss: 5.9824e-04
# Epoch 19/20
# 14216/14216 [==============================] - 33s 2ms/step - loss: 5.6853e-04
# Epoch 20/20
# 14216/14216 [==============================] - 35s 2ms/step - loss: 5.3744e-04

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))
# Out:
# Accuracy Neural Net: 0.9983497770443454
# Precision Neural Net: 0.0
# Recall Neural Net: 0.0
# F1 Score Neural Net: 0.0

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.9489836672907321

# %%
#let's  try multi layer perceptron as well
from sklearn.neural_network import MLPClassifier

# %%
predict(MLPClassifier(solver='lbfgs', hidden_layer_sizes=(100,100), random_state=2),X_train,X_test,y_train,y_test)
# Out:
# [[56863     5]
#  [   22    72]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.94      0.77      0.84        94
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.88      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# roc_score 0.8829347619496587
# Precision : 0.935064935064935
# Recall : 0.7659574468085106
# 0.9995259997893332

# %%
predict(MLPClassifier(solver='lbfgs', hidden_layer_sizes=(100,100), random_state=2),X_smote,X_test,Y_smote,y_test)
# Out:
# [[56840    28]
#  [   19    75]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.73      0.80      0.76        94
#
#     accuracy                           1.00     56962
#    macro avg       0.86      0.90      0.88     56962
# weighted avg       1.00      1.00      1.00     56962
#
# roc_score 0.898689986067025
# Precision : 0.7281553398058253
# Recall : 0.7978723404255319
# 0.9991748885221726

# %%
predict(Knn(n_neighbors=5),X_smote,X_test,Y_smote,y_test)
# Out:
# [[56745   123]
#  [   13    81]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56868
#            1       0.40      0.86      0.54        94
#
#     accuracy                           1.00     56962
#    macro avg       0.70      0.93      0.77     56962
# weighted avg       1.00      1.00      1.00     56962
#
# roc_score 0.9297696120467106
# Precision : 0.39705882352941174
# Recall : 0.8617021276595744
# 0.9976124433833081

# %%
predict(GaussianNB(),X_smote,X_test,Y_smote,y_test )
# Out:
# [[55400  1468]
#  [   15    79]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56868
#            1       0.05      0.84      0.10        94
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.91      0.54     56962
# weighted avg       1.00      0.97      0.99     56962
#
# roc_score 0.9073056828878822
# Precision : 0.05106658047834518
# Recall : 0.8404255319148937
# 0.9739650995400443

# %%
#now let's try with some dense networks
model = Sequential()
model.add(Dense(32, input_shape=(30,), activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(16, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(8, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(4, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs = 10,  validation_split = 0.15, verbose = 1,
                    )
history_dict = history.history
# Out:
# Epoch 1/10
# 6053/6053 [==============================] - 23s 4ms/step - loss: 0.0327 - accuracy: 0.9928 - val_loss: 0.0045 - val_accuracy: 0.9989
# Epoch 2/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.0034 - val_accuracy: 0.9987
# Epoch 3/10
# 6053/6053 [==============================] - 23s 4ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.0031 - val_accuracy: 0.9988
# Epoch 4/10
# 6053/6053 [==============================] - 24s 4ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0033 - val_accuracy: 0.9992
# Epoch 5/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0029 - val_accuracy: 0.9991
# Epoch 6/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.0033 - val_accuracy: 0.9992
# Epoch 7/10
# 6053/6053 [==============================] - 25s 4ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 8/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9993
# Epoch 9/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.0035 - val_accuracy: 0.9993
# Epoch 10/10
# 6053/6053 [==============================] - 24s 4ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0032 - val_accuracy: 0.9994

# %%
loss_values = history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
val_accuracy_values=history_dict['val_accuracy']
plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))
# Out:
# Accuracy Neural Net: 0.9983497770443454
# Precision Neural Net: 0.0
# Recall Neural Net: 0.0
# F1 Score Neural Net: 0.0

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.9681431916240522

# %%
#let's try same with balanced datasets as well

# %%
history = model.fit(X_smote, Y_smote, epochs = 10,  validation_split = 0.15, verbose = 1,
                    )
history_dict = history.history
# Out:
# Epoch 1/10
# 12084/12084 [==============================] - 45s 4ms/step - loss: 0.0885 - accuracy: 0.9620 - val_loss: 0.0071 - val_accuracy: 0.9996
# Epoch 2/10
# 12084/12084 [==============================] - 50s 4ms/step - loss: 0.0325 - accuracy: 0.9907 - val_loss: 0.0043 - val_accuracy: 0.9996
# Epoch 3/10
# 12084/12084 [==============================] - 42s 4ms/step - loss: 0.0308 - accuracy: 0.9913 - val_loss: 0.0063 - val_accuracy: 0.9986
# Epoch 4/10
# 12084/12084 [==============================] - 43s 4ms/step - loss: 0.0289 - accuracy: 0.9920 - val_loss: 0.0109 - val_accuracy: 0.9995
# Epoch 5/10
# 12084/12084 [==============================] - 48s 4ms/step - loss: 0.0285 - accuracy: 0.9923 - val_loss: 0.0037 - val_accuracy: 0.9995
# Epoch 6/10
# 12084/12084 [==============================] - 43s 4ms/step - loss: 0.0268 - accuracy: 0.9928 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 7/10
# 12084/12084 [==============================] - 43s 4ms/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.0017 - val_accuracy: 0.9999
# Epoch 8/10
# 12084/12084 [==============================] - 49s 4ms/step - loss: 0.0266 - accuracy: 0.9928 - val_loss: 0.0035 - val_accuracy: 0.9997
# Epoch 9/10
# 12084/12084 [==============================] - 41s 3ms/step - loss: 0.0257 - accuracy: 0.9930 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 10/10
# 12084/12084 [==============================] - 43s 4ms/step - loss: 0.0262 - accuracy: 0.9929 - val_loss: 0.0019 - val_accuracy: 0.9999

# %%
loss_values = history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
val_accuracy_values=history_dict['val_accuracy']
plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))
# Out:
# Accuracy Neural Net: 0.9983497770443454
# Precision Neural Net: 0.0
# Recall Neural Net: 0.0
# F1 Score Neural Net: 0.0

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.9515456847436168

# %% [markdown]
# now for unsupervised method

# %%
fraud=df[df['Class']==1]
normal = df[df['Class']==0]

# %%
n_outliers = len(fraud)

# %%
outlier_fraction = len(fraud)/float(len(normal))

# %%
print(fraud.shape,normal.shape)
# Out:
# (492, 31) (284315, 31)

# %%
normal_train,normal_test= train_test_split(normal, test_size= 0.30,random_state= 42)

# %%
model = IsolationForest()
model.fit(normal_train)
normal_pred_test = model.predict(normal_test)
fraud_pred = model.predict(fraud)

# %%
print("Accuracy in Detecting Legit Cases:", list(normal_pred_test).count(1)/normal_pred_test.shape[0])
print("Accuracy in Detecting Fraud Cases:", list(fraud_pred).count(-1)/fraud_pred.shape[0])
# Out:
# Accuracy in Detecting Legit Cases: 0.9660120757371475
# Accuracy in Detecting Fraud Cases: 0.8048780487804879

# %%
model =LocalOutlierFactor(novelty=True)
model.fit(normal_train)
normal_pred_test = model.predict(normal_test)
fraud_pred = model.predict(fraud)

# %%
print("Accuracy in Detecting Legit Cases:", list(normal_pred_test).count(1)/normal_pred_test.shape[0])
print("Accuracy in Detecting Fraud Cases:", list(fraud_pred).count(-1)/fraud_pred.shape[0])
# Out:
# Accuracy in Detecting Legit Cases: 0.9505129257283546
# Accuracy in Detecting Fraud Cases: 0.31910569105691056

# %% [markdown]
# now doing same for balanced dataset as well

# %%
X_Smote2 = X_smote
X_Smote2['Class'] = Y_smote

# %%
sns.countplot(X_Smote2['Class'])
plt.show()

# %%
fraud=X_Smote2[X_Smote2['Class']==1]
normal = X_Smote2[X_Smote2['Class']==0]

# %%
n_outliers = len(fraud)

# %%
outlier_fraction = len(fraud)/float(len(normal))

# %%
#same for smote balanced datasets as well
normal_train,normal_test= train_test_split(normal, test_size= 0.30,random_state= 42)

# %%
model = IsolationForest()
model.fit(normal_train)
normal_pred_test = model.predict(normal_test)
fraud_pred = model.predict(fraud)

# %%
print("Accuracy in Detecting Legit Cases:", list(normal_pred_test).count(1)/normal_pred_test.shape[0])
print("Accuracy in Detecting Fraud Cases:", list(fraud_pred).count(-1)/fraud_pred.shape[0])
# Out:
# Accuracy in Detecting Legit Cases: 0.9627463911482377
# Accuracy in Detecting Fraud Cases: 0.8170914542728636

# %%
model =LocalOutlierFactor(novelty=True)
model.fit(normal_train)
normal_pred_test = model.predict(normal_test)
fraud_pred = model.predict(fraud)

# %%
print("Accuracy in Detecting Legit Cases:", list(normal_pred_test).count(1)/normal_pred_test.shape[0])
print("Accuracy in Detecting Fraud Cases:", list(fraud_pred).count(-1)/fraud_pred.shape[0])
# Out:
# Accuracy in Detecting Legit Cases: 0.9513446178647321
# Accuracy in Detecting Fraud Cases: 0.3143237765281582

# %% [markdown]
# Using auto encoders now

# %%
#using auto encoders

model = Sequential()
model.add(Dense(100, input_shape=(30,), activation='tanh',activity_regularizer=regularizers.l1(10e-5))),

## encoding part

model.add(Dense(50, activation='relu')),

## decoding part
model.add(Dense(50, activation='tanh')),
model.add(Dense(100, activation='tanh')),

## output layer
model.add(Dense(1, activation='relu'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs = 10,  validation_split = 0.15, verbose = 1,
                    )
history_dict = history.history
# Out:
# Epoch 1/10
# 6053/6053 [==============================] - 23s 4ms/step - loss: 0.0292 - accuracy: 0.9982 - val_loss: 0.0245 - val_accuracy: 0.9984
# Epoch 2/10
# 6053/6053 [==============================] - 21s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 3/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 4/10
# 6053/6053 [==============================] - 21s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 5/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 6/10
# 6053/6053 [==============================] - 25s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 7/10
# 6053/6053 [==============================] - 24s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 8/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 9/10
# 6053/6053 [==============================] - 22s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984
# Epoch 10/10
# 6053/6053 [==============================] - 21s 4ms/step - loss: 0.0274 - accuracy: 0.9982 - val_loss: 0.0244 - val_accuracy: 0.9984

# %%
loss_values = history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
val_accuracy_values=history_dict['val_accuracy']
plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))
# Out:
# Accuracy Neural Net: 0.9983497770443454
# Precision Neural Net: 0.0
# Recall Neural Net: 0.0
# F1 Score Neural Net: 0.0

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.5

# %%
#now let's try with some dense networks
model = Sequential()
model.add(Dense(32, input_shape=(30,), activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(16, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(8, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(4, activation='relu')),


#decoding part
model.add(Dense(2,activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(4, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(8, activation='relu')),
model.add(Dropout(0.2)),

model.add(Dense(16, activation='relu')),
model.add(Dropout(0.2)),
model.add(Dense(32, activation='relu')),
model.add(Dropout(0.2)),

model.add(Dense(1, activation ='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 32)                992
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2)                 0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 12
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_18 (Dense)             (None, 8)                 40
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                144
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 32)                544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 2,475
# Trainable params: 2,475
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs = 10,validation_split = 0.15, verbose = 1,
                    )
history_dict = history.history
# Out:
# Epoch 1/10
# 6053/6053 [==============================] - 28s 4ms/step - loss: 0.0222 - accuracy: 0.9982 - val_loss: 0.0084 - val_accuracy: 0.9984
# Epoch 2/10
# 6053/6053 [==============================] - 27s 4ms/step - loss: 0.0121 - accuracy: 0.9982 - val_loss: 0.0088 - val_accuracy: 0.9984
# Epoch 3/10
# 6053/6053 [==============================] - 27s 4ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.0074 - val_accuracy: 0.9984
# Epoch 4/10
# 6053/6053 [==============================] - 26s 4ms/step - loss: 0.0109 - accuracy: 0.9982 - val_loss: 0.0087 - val_accuracy: 0.9984
# Epoch 5/10
# 6053/6053 [==============================] - 35s 6ms/step - loss: 0.0107 - accuracy: 0.9982 - val_loss: 0.0083 - val_accuracy: 0.9984
# Epoch 6/10
# 6053/6053 [==============================] - 26s 4ms/step - loss: 0.0106 - accuracy: 0.9982 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 7/10
# 6053/6053 [==============================] - 27s 4ms/step - loss: 0.0104 - accuracy: 0.9982 - val_loss: 0.0078 - val_accuracy: 0.9984
# Epoch 8/10
# 6053/6053 [==============================] - 27s 4ms/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.0088 - val_accuracy: 0.9984
# Epoch 9/10
# 6053/6053 [==============================] - 27s 4ms/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 10/10
# 6053/6053 [==============================] - 33s 6ms/step - loss: 0.0106 - accuracy: 0.9982 - val_loss: 0.0091 - val_accuracy: 0.9984

# %%
loss_values = history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
val_accuracy_values=history_dict['val_accuracy']
plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.969756015797689

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))
# Out:
# Accuracy Neural Net: 0.9983497770443454
# Precision Neural Net: 0.0
# Recall Neural Net: 0.0
# F1 Score Neural Net: 0.0

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)
# Out:
# AUC Neural Net:  0.969756015797689

# %%
#trying same for balanced datsets
history = model.fit(X_smote, Y_smote, epochs = 10, validation_split = 0.15, verbose = 1,
                    )
history_dict = history.history
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27/2059853784.py in <module>
#       1 #trying same for balanced datsets
# ----> 2 history = model.fit(X_smote, Y_smote, epochs = 10, validation_split = 0.15, verbose = 1,
#       3                     )
#       4 history_dict = history.history
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3036     with self._lock:
#    3037       (graph_function,
# -> 3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3458               call_context_key in self._function_cache.missed):
#    3459             return self._define_function_with_shape_relaxation(
# -> 3460                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3380
#    3381     graph_function = self._create_graph_function(
# -> 3382         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3383     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3384
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     992           except Exception as e:  # pylint:disable=broad-except
#     993             if hasattr(e, "ag_error_metadata"):
# --> 994               raise e.ag_error_metadata.to_exception(e)
#     995             else:
#     996               raise
#
# ValueError: in user code:
#
#     /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:853 train_function  *
#         return step_function(self, iterator)
#     /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:842 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /opt/conda/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:1286 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /opt/conda/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:2849 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /opt/conda/lib/python3.7/site-packages/tensorflow/python/distribute/distribute_lib.py:3632 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:835 run_step  **
#         outputs = model.train_step(data)
#     /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:787 train_step
#         y_pred = self(x, training=True)
#     /opt/conda/lib/python3.7/site-packages/keras/engine/base_layer.py:1020 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /opt/conda/lib/python3.7/site-packages/keras/engine/input_spec.py:254 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_3 is incompatible with the layer: expected axis -1 of input shape to have value 30 but received input with shape (None, 31)

# %%
loss_values = history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")

# %%
accuracy_values = history_dict['accuracy']
val_accuracy_values=history_dict['val_accuracy']
plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")

# %%
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# %%
print("Accuracy Neural Net:",metrics.accuracy_score(y_test, y_pred_nn))
print("Precision Neural Net:",metrics.precision_score(y_test, y_pred_nn))
print("Recall Neural Net:",metrics.recall_score(y_test, y_pred_nn))
print("F1 Score Neural Net:",metrics.f1_score(y_test, y_pred_nn))

# %%
#AUC

y_pred_nn_proba = model.predict(X_test)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test,y_pred_nn_proba)
auc_keras = auc(fpr_keras, tpr_keras)
print('AUC Neural Net: ', auc_keras)

# %% [markdown]
# AUC improved to 91 which is quite good
